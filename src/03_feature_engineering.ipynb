# %% [markdown]
# ## ||| - Feature Engineering

# %% [markdown]
# Création de la variable nb_service_internet

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("../data/silver.csv")
df.head()
# Out:
#    gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female            No     Yes         No       1           No
# 1    Male            No      No         No      34          Yes
# 2    Male            No      No         No       2          Yes
# 3    Male            No      No         No      45           No
# 4  Female            No      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
def add_nb_service_column(df):
    services = ['PhoneService', 'OnlineSecurity', 'OnlineBackup', 
                'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies']
    df['nb-service'] = df[services].apply(lambda x: x.eq('Yes').sum(), axis=1)
    df = df.drop(columns=services)
    return df

# %%
df = add_nb_service_column(df)
df.head()
# Out:
#    gender SeniorCitizen Partner Dependents  tenure     MultipleLines  \
# 0  Female            No     Yes         No       1  No phone service
# 1    Male            No      No         No      34                No
# 2    Male            No      No         No       2                No
# 3    Male            No      No         No      45  No phone service
# 4  Female            No      No         No       2                No
#
#   InternetService        Contract PaperlessBilling              PaymentMethod  \
# 0             DSL  Month-to-month              Yes           Electronic check
# 1             DSL        One year               No               Mailed check
# 2             DSL  Month-to-month              Yes               Mailed check
# 3             DSL        One year               No  Bank transfer (automatic)
# 4     Fiber optic  Month-to-month              Yes           Electronic check
#
#    MonthlyCharges  TotalCharges Churn  nb-service
# ...
